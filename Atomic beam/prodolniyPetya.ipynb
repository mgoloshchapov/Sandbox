# %%
import numpy as np
import pandas as pd
import scipy.stats as sps
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.optimize import curve_fit, dual_annealing
from scipy.special import voigt_profile
from scipy.signal import savgol_filter
from scipy.optimize import dual_annealing

red = '#FF3300'
blue = '#0099CC'
green = '#00CC66'

# %%
data0 = [
    pd.read_csv("data/P0-60.CSV"),
    pd.read_csv("data/P0-61.CSV"),
    pd.read_csv("data/P0-62.CSV"),
    pd.read_csv("data/P0-63.CSV"),
    pd.read_csv("data/P0-64.CSV"),
    pd.read_csv("data/P0-65.CSV"),
    pd.read_csv("data/P0-66.CSV"),
    pd.read_csv("data/P0-67.CSV"),
    pd.read_csv("data/P0-68.CSV"),
    pd.read_csv("data/P0-69.CSV"),
    pd.read_csv("data/P0-70.CSV"),
    pd.read_csv("data/P0-71.CSV"),
    pd.read_csv("data/P0-72.CSV"),
    pd.read_csv("data/P0-73.CSV"),
    pd.read_csv("data/P0-74.CSV"),
    pd.read_csv("data/P0-75.CSV"),
    pd.read_csv("data/P0-76.CSV"),
    pd.read_csv("data/P0-77.CSV"),
    pd.read_csv("data/P0-78.CSV"),
    pd.read_csv("data/P0-79.CSV"),
    pd.read_csv("data/P0-80.CSV"),
    pd.read_csv("data/P0-81.CSV")
]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <module>
#       1 data0 = [
# ----> 2     pd.read_csv("data/P0-60.CSV"),
#       3     pd.read_csv("data/P0-61.CSV"),
#       4     pd.read_csv("data/P0-62.CSV"),
#       5     pd.read_csv("data/P0-63.CSV"),
#       6     pd.read_csv("data/P0-64.CSV"),
#       7     pd.read_csv("data/P0-65.CSV"),
#       8     pd.read_csv("data/P0-66.CSV"),
#       9     pd.read_csv("data/P0-67.CSV"),
#      10     pd.read_csv("data/P0-68.CSV"),
#      11     pd.read_csv("data/P0-69.CSV"),
#      12     pd.read_csv("data/P0-70.CSV"),
#      13     pd.read_csv("data/P0-71.CSV"),
#      14     pd.read_csv("data/P0-72.CSV"),
#      15     pd.read_csv("data/P0-73.CSV"),
#      16     pd.read_csv("data/P0-74.CSV"),
#      17     pd.read_csv("data/P0-75.CSV"),
#      18     pd.read_csv("data/P0-76.CSV"),
# ...

# %%
x0 = []
y0 = []
t0 = []

# %%
for i in range(len(data0)):
    x0.append(np.array(data0[i].iloc[20000:,1])-data0[i].iloc[20000,1])
    t0.append(np.array(data0[i].iloc[20000:,0])-data0[i].iloc[20000,0])
    y0.append(np.array(data0[i].iloc[50000:,3]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(x0)):
    plt.plot(x0[i])

# %%
plt.figure(figsize=(10,6))
for i in range(len(x0)):
    plt.plot(y0[i])

# %%
mi = []
ma = []

# %%
for i in range(len(y0)):
    mi.append(np.argmin(y0[i]))
    ma.append(np.argmax(y0[i]))

# %%
plt.figure(figsize=(10,6))
plt.plot(y0[3])
plt.scatter([mi[3],ma[3]],[np.min(y0[3]), np.max(y0[3])], color="red",s=50)

# %%
omega0 = []

# %%
for i in range(len(y0)):
    omega0.append((t0[i]-t0[i][ma[i]+30000])*114.1/(-t0[i][ma[i]]+t0[i][mi[i]]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(x0)):
    plt.plot(omega0[i],x0[i])

# %%
plt.figure(figsize=(10,6))
for i in range(len(x0)//2, len(x0)):
    plt.plot(x0[i], label=i)
plt.legend()

# %%
plt.plot(omega0[1],x0[1])

# %%
h0=[]

# %%
h0.append(np.max(x0[0])/np.max(x0[0][60000:]))
h0.append(np.max(x0[1])/np.max(x0[1][60000:]))
h0.append(np.max(x0[2])/np.max(x0[2][60000:]))
h0.append(np.max(x0[3])/np.max(x0[3][60000:]))
h0.append(np.max(x0[4])/np.max(x0[4][60000:]))
h0.append(np.max(x0[5])/np.max(x0[5][60000:]))
h0.append(np.max(x0[6])/np.max(x0[6][60000:]))
h0.append(np.max(x0[7])/np.max(x0[7][60000:]))
h0.append(np.max(x0[8])/np.max(x0[8][60000:]))
h0.append(np.max(x0[9])/np.max(x0[9][60000:]))
h0.append(np.max(x0[10])/np.max(x0[10][60000:]))
h0.append(np.max(x0[11])/np.max(x0[11][55000:]))
h0.append(np.max(x0[12])/np.max(x0[12][55000:]))
h0.append(np.max(x0[13])/np.max(x0[13][55000:]))
h0.append(np.max(x0[14])/np.max(x0[14][55000:]))
h0.append(np.max(x0[15])/np.max(x0[15][55000:]))
h0.append(np.max(x0[16])/np.max(x0[16][60000:]))
h0.append(np.max(x0[17])/np.max(x0[17][60000:]))
h0.append(np.max(x0[18])/np.max(x0[18][60000:]))
h0.append(np.max(x0[19])/np.max(x0[19][60000:]))
h0.append(np.max(x0[20])/np.max(x0[20][60000:]))
h0.append(np.max(x0[21])/np.max(x0[21][60000:]))

# %%
plt.plot(h0)

# %%
data1 = [
    pd.read_csv("data/P1-60.CSV"),
    pd.read_csv("data/P1-61.CSV"),
    pd.read_csv("data/P1-62.CSV"),
    pd.read_csv("data/P1-63.CSV"),
    pd.read_csv("data/P1-64.CSV"),
    pd.read_csv("data/P1-65.CSV"),
    pd.read_csv("data/P1-66.CSV"),
    pd.read_csv("data/P1-67.CSV"),
    pd.read_csv("data/P1-68.CSV"),
    pd.read_csv("data/P1-69.CSV"),
    pd.read_csv("data/P1-70.CSV"),
    pd.read_csv("data/P1-71.CSV"),
    pd.read_csv("data/P1-72.CSV"),
    pd.read_csv("data/P1-73.CSV"),
    pd.read_csv("data/P1-74.CSV"),
    pd.read_csv("data/P1-75.CSV"),
    pd.read_csv("data/P1-76.CSV"),
    pd.read_csv("data/P1-77.CSV"),
    pd.read_csv("data/P1-78.CSV"),
    pd.read_csv("data/P1-79.CSV"),
    pd.read_csv("data/P1-80.CSV"),
    pd.read_csv("data/P1-81.CSV"),
    pd.read_csv("data/P1-82.CSV")
]

# %%
x1, y1, t1, ma1,mi1,omega1 = [],[],[],[],[],[]

# %%
for i in range(len(data1)):
    x1.append(np.array(data1[i].iloc[20000:,1])-data1[i].iloc[20000,1])
    t1.append(np.array(data1[i].iloc[20000:,0])-data1[i].iloc[20000,0])
    y1.append(np.array(data1[i].iloc[50000:,3]))

for i in range(len(y1)):
    mi1.append(np.argmin(y1[i]))
    ma1.append(np.argmax(y1[i]))

for i in range(len(y1)):
    omega1.append((t1[i]-t1[i][ma1[i]+30000])*114.1/(-t1[i][ma1[i]]+t1[i][mi1[i]]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(x1)):
    plt.plot(omega1[i],x1[i])

# %%
plt.figure(figsize=(10,6))
for i in range(len(x1)):
    plt.plot(x1[i], label=i)
plt.legend()
# Out:
# C:\Users\Peter\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
h1=[]

# %%
h1.append(np.max(x1[0])/np.max(x1[0][70000:]))
h1.append(np.max(x1[1])/np.max(x1[1][70000:]))
h1.append(np.max(x1[2])/np.max(x1[2][60000:]))
h1.append(np.max(x1[3])/np.max(x1[3][60000:]))
h1.append(np.max(x1[4])/np.max(x1[4][60000:]))
h1.append(np.max(x1[5])/np.max(x1[5][60000:]))
h1.append(np.max(x1[6])/np.max(x1[6][60000:]))
h1.append(np.max(x1[7])/np.max(x1[7][60000:]))
h1.append(np.max(x1[8])/np.max(x1[8][60000:]))
h1.append(np.max(x1[9])/np.max(x1[9][60000:]))
h1.append(np.max(x1[10])/np.max(x1[10][50000:]))
h1.append(np.max(x1[11])/np.max(x1[11][50000:]))
h1.append(np.max(x1[12])/np.max(x1[12][50000:]))
h1.append(np.max(x1[13])/np.max(x1[13][50000:]))
h1.append(np.max(x1[14])/np.max(x1[14][50000:]))
h1.append(np.max(x1[15])/np.max(x1[15][60000:]))
h1.append(np.max(x1[16])/np.max(x1[16][60000:]))
h1.append(np.max(x1[17])/np.max(x1[17][50000:]))
h1.append(np.max(x1[18])/np.max(x1[18][50000:]))
h1.append(np.max(x1[19])/np.max(x1[19][50000:]))
h1.append(np.max(x1[20])/np.max(x1[20][50000:]))
h1.append(np.max(x1[21])/np.max(x1[21][50000:]))
h1.append(np.max(x1[22])/np.max(x1[22][50000:]))

# %%
plt.plot(h1)

# %%
data2 = [
    pd.read_csv("data/P2-60.CSV"),
    pd.read_csv("data/P2-61.CSV"),
    pd.read_csv("data/P2-62.CSV"),
    pd.read_csv("data/P2-63.CSV"),
    pd.read_csv("data/P2-64.CSV"),
    pd.read_csv("data/P2-65.CSV"),
    pd.read_csv("data/P2-66.CSV"),
    pd.read_csv("data/P2-67.CSV"),
    pd.read_csv("data/P2-68.CSV"),
    pd.read_csv("data/P2-69.CSV"),
    pd.read_csv("data/P2-70.CSV"),
    pd.read_csv("data/P2-71.CSV"),
    pd.read_csv("data/P2-72.CSV"),
    pd.read_csv("data/P2-73.CSV"),
    pd.read_csv("data/P2-74.CSV"),
    pd.read_csv("data/P2-75.CSV"),
    pd.read_csv("data/P2-76.CSV"),
    pd.read_csv("data/P2-77.CSV"),
    pd.read_csv("data/P2-78.CSV"),
    pd.read_csv("data/P2-79.CSV"),
    pd.read_csv("data/P2-80.CSV"),
    pd.read_csv("data/P2-81.CSV"),
    pd.read_csv("data/P2-82.CSV")
]

# %%
x2, y2, t2, ma2,mi2,omega2, h2 = [],[],[],[],[],[],[]

# %%
for i in range(len(data2)):
    x2.append(np.array(data2[i].iloc[20000:,1])-data2[i].iloc[20000,1])
    t2.append(np.array(data2[i].iloc[20000:,0])-data2[i].iloc[20000,0])
    y2.append(np.array(data2[i].iloc[50000:,3]))

for i in range(len(y2)):
    mi2.append(np.argmin(y2[i]))
    ma2.append(np.argmax(y2[i]))

for i in range(len(y2)):
    omega2.append((t2[i]-t2[i][ma2[i]+30000])*114.1/(-t2[i][ma2[i]]+t2[i][mi2[i]]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(x2)):
    plt.plot(omega2[i],x2[i])

# %%
plt.figure(figsize=(10,6))
for i in range(len(x2)//2, len(x2)):
    plt.plot(x2[i], label=i)
plt.legend()

# %%
h2.append(np.max(x2[0])/np.max(x2[0][50000:]))
h2.append(np.max(x2[1])/np.max(x2[1][50000:]))
h2.append(np.max(x2[2])/np.max(x2[2][50000:]))
h2.append(np.max(x2[3])/np.max(x2[3][50000:]))
h2.append(np.max(x2[4])/np.max(x2[4][50000:]))
h2.append(np.max(x2[5])/np.max(x2[5][50000:]))
h2.append(np.max(x2[6])/np.max(x2[6][50000:]))
h2.append(np.max(x2[7])/np.max(x2[7][50000:]))
h2.append(np.max(x2[8])/np.max(x2[8][50000:]))
h2.append(np.max(x2[9])/np.max(x2[9][50000:]))
h2.append(np.max(x2[10])/np.max(x2[10][50000:]))
h2.append(np.max(x2[11])/np.max(x2[11][50000:]))
h2.append(np.max(x2[12])/np.max(x2[12][50000:]))
h2.append(np.max(x2[13])/np.max(x2[13][50000:]))
h2.append(np.max(x2[14])/np.max(x2[14][50000:]))
h2.append(np.max(x2[15])/np.max(x2[15][50000:]))
h2.append(np.max(x2[16])/np.max(x2[16][50000:]))
h2.append(np.max(x2[17])/np.max(x2[17][60000:]))
h2.append(np.max(x2[18])/np.max(x2[18][60000:]))
h2.append(np.max(x2[19])/np.max(x2[19][60000:]))
h2.append(np.max(x2[20])/np.max(x2[20][60000:]))
h2.append(np.max(x2[21])/np.max(x2[21][60000:]))
h2.append(np.max(x2[22])/np.max(x2[22][60000:]))

# %%
plt.plot(h2)

# %%
data6 = [
    pd.read_csv("data/P6-65.CSV"),
    pd.read_csv("data/P6-66.CSV"),
    pd.read_csv("data/P6-67.CSV"),
    pd.read_csv("data/P6-68.CSV"),
    pd.read_csv("data/P6-69.CSV"),
    pd.read_csv("data/P6-70.CSV"),
    pd.read_csv("data/P6-71.CSV"),
    pd.read_csv("data/P6-72.CSV"),
    pd.read_csv("data/P6-73.CSV"),
    pd.read_csv("data/P6-74.CSV"),
    pd.read_csv("data/P6-75.CSV"),
    pd.read_csv("data/P6-76.CSV"),
    pd.read_csv("data/P6-77.CSV"),
    pd.read_csv("data/P6-78.CSV"),
    pd.read_csv("data/P6-79.CSV"),
    pd.read_csv("data/P6-80.CSV"),
    pd.read_csv("data/P6-81.CSV"),
    pd.read_csv("data/P6-82.CSV")
]

# %%
x6, y6, t6, ma6,mi6,omega6 = [],[],[],[],[],[]
h6 = []

# %%
for i in range(len(data6)):
    x6.append(np.array(data6[i].iloc[20000:,1])-data6[i].iloc[20000,1])
    t6.append(np.array(data6[i].iloc[20000:,0])-data6[i].iloc[20000,0])
    y6.append(np.array(data6[i].iloc[50000:,3]))

for i in range(len(y6)):
    mi6.append(np.argmin(y6[i]))
    ma6.append(np.argmax(y6[i]))

for i in range(len(y6)):
    omega6.append((t6[i]-t6[i][ma6[i]+30000])*114.1/(-t6[i][ma6[i]]+t6[i][mi6[i]]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(x6)//2):
    plt.plot(omega6[i*2],x6[i*2], label=i)
plt.legend()

# %%
for i in range(len(x6)):
    h6.append(np.max(x6[i])/np.max(x6[i][60000:]))

# %%
plt.plot(h6)

# %% [markdown]
# _________________________________________________

# %%
data9=[
    pd.read_csv("data/new/P9-600.CSV"),
    pd.read_csv("data/new/P9-605.CSV"),
    pd.read_csv("data/new/P9-610.CSV"),
    pd.read_csv("data/new/P9-615.CSV"),
    pd.read_csv("data/new/P9-620.CSV"),
    pd.read_csv("data/new/P9-625.CSV"),
    pd.read_csv("data/new/P9-630.CSV"),
    pd.read_csv("data/new/P9-635.CSV"),
    pd.read_csv("data/new/P9-640.CSV"),
    pd.read_csv("data/new/P9-645.CSV"),
    pd.read_csv("data/new/P9-650.CSV"),
    pd.read_csv("data/new/P9-655.CSV"),
    pd.read_csv("data/new/P9-660.CSV"),
    pd.read_csv("data/new/P9-665.CSV"),
    pd.read_csv("data/new/P9-670.CSV"),
    pd.read_csv("data/new/P9-675.CSV"),
    pd.read_csv("data/new/P9-680.CSV"),
    pd.read_csv("data/new/P9-685.CSV"),
    pd.read_csv("data/new/P9-690.CSV"),
    pd.read_csv("data/new/P9-695.CSV"),
    pd.read_csv("data/new/P9-700.CSV"),
    pd.read_csv("data/new/P9-705.CSV"),
    pd.read_csv("data/new/P9-710.CSV"),
    pd.read_csv("data/new/P9-715.CSV"),
    pd.read_csv("data/new/P9-720.CSV"),
    pd.read_csv("data/new/P9-725.CSV"),
    pd.read_csv("data/new/P9-730.CSV"),
    pd.read_csv("data/new/P9-735.CSV"),
    pd.read_csv("data/new/P9-740.CSV"),
    pd.read_csv("data/new/P9-745.CSV"),
    pd.read_csv("data/new/P9-750.CSV"),
    pd.read_csv("data/new/P9-755.CSV"),
    pd.read_csv("data/new/P9-760.CSV"),
    pd.read_csv("data/new/P9-765.CSV"),
    pd.read_csv("data/new/P9-770.CSV"),
    pd.read_csv("data/new/P9-775.CSV"),
    pd.read_csv("data/new/P9-780.CSV"),
    pd.read_csv("data/new/P9-785.CSV"),
    pd.read_csv("data/new/P9-790.CSV"),
    pd.read_csv("data/new/P9-795.CSV"),
    pd.read_csv("data/new/P9-800.CSV"),
    pd.read_csv("data/new/P9-805.CSV"),
    pd.read_csv("data/new/P9-810.CSV"),
    pd.read_csv("data/new/P9-815.CSV"),
    pd.read_csv("data/new/P9-820.CSV"),
    pd.read_csv("data/new/P9-825.CSV"),
    pd.read_csv("data/new/P9-830.CSV"),
    pd.read_csv("data/new/P9-835.CSV"),
    pd.read_csv("data/new/P9-840.CSV"),
    pd.read_csv("data/new/P9-845.CSV"),
    pd.read_csv("data/new/P9-850.CSV"),
    pd.read_csv("data/new/P9-855.CSV"),
    pd.read_csv("data/new/P9-860.CSV"),
    pd.read_csv("data/new/P9-865.CSV"),
    pd.read_csv("data/new/P9-870.CSV"),
    pd.read_csv("data/new/P9-875.CSV"),
    pd.read_csv("data/new/P9-880.CSV"),
    pd.read_csv("data/new/P9-885.CSV"),
    pd.read_csv("data/new/P9-890.CSV"),
    pd.read_csv("data/new/P9-895.CSV"),
    pd.read_csv("data/new/P9-900.CSV"),
    pd.read_csv("data/new/P9-905.CSV"),
    pd.read_csv("data/new/P9-910.CSV"),
    pd.read_csv("data/new/P9-915.CSV"),
    pd.read_csv("data/new/P9-920.CSV")
]

# %%
x9, y9, t9, ma9,mi9,omega9 = [],[],[],[],[],[]

# %%
plt.figure(figsize=(10,6))
for i in range(len(data9)//2+22, len(data9)):
    plt.plot(data9[i].iloc[:,3])

# %%
for i in range(len(data9)//2+22):
    x9.append(np.array(data9[i].iloc[20000:,1])-data9[i].iloc[20000,1])
    t9.append(np.array(data9[i].iloc[20000:,0])-data9[i].iloc[20000,0])
    y9.append(np.array(data9[i].iloc[50000:,3]))
for i in range(len(data9)//2+22, len(data9)):
    x9.append(np.array(data9[i].iloc[20000:,1])-data9[i].iloc[20000,1])
    t9.append(np.array(data9[i].iloc[20000:,0])-data9[i].iloc[20000,0])
    y9.append(np.array(data9[i].iloc[40000:,3]))

# %%
for i in range(len(x9)):
    mi9.append(np.argmin(y9[i]))
for i in range(44):
    ma9.append(np.argmax(y9[i]))

# %%
for i in range(44):
    omega9.append((t9[i]-t9[i][ma9[i]+30000])*114.1/(-t9[i][ma9[i]]+t9[i][mi9[i]]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(x9)//3):
    plt.plot(omega9[i],x9[i], label=i)
plt.legend()
# Out:
# C:\Users\Peter\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,6))
for i in range(len(x9)//3, len(x9)//3*2-1):
    plt.plot(omega9[i],x9[i], label=i)
plt.legend()
# Out:
# C:\Users\Peter\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot(x9[41])
plt.scatter([51800],[x9[41][51800]], color='red')

# %%
plt.figure(figsize=(10,6))
for i in range(len(x9)//3*2, 45):
    plt.plot(omega9[i],x9[i], label=i)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [32], in <module>
#       1 plt.figure(figsize=(10,6))
#       2 for i in range(len(x9)//3*2, 45):
# ----> 3     plt.plot(omega9[i],x9[i], label=i)
#       4 plt.legend()
#
# IndexError: list index out of range

# %%
h9 = []

# %%
for i in range(len(x9)//3*2-1):
    h9.append(np.max(x9[i])/np.max(x9[i][np.argmin(np.abs(omega9[i]-170)):]))

# %%
h9.append(x9[41][51800]/np.max(x9[41][np.argmin(np.abs(omega9[41]-170)):]))

# %%
h9.append(np.max(x9[42])/np.max(x9[42][np.argmin(np.abs(omega9[42]-170)):]))
h9.append(np.max(x9[43])/np.max(x9[43][np.argmin(np.abs(omega9[43]-170)):]))

# %%
plt.plot(h9)

# %%
plt.plot(y9[54])

# %%
for i in range(44, 54):
    ma9.append(np.argmax(y9[i][0:30000]))
    omega9.append((t9[i]-t9[i][ma9[i]+30000])*114.1/(-t9[i][ma9[i]]+t9[i][mi9[i]]))

# %%
for i in range(44, 54):
    plt.plot(omega9[i],x9[i], label=i)
plt.legend()

# %%
for i in range(44, 53):
    h9.append(np.max(x9[i])/np.max(x9[i][np.argmin(np.abs(omega9[i]-170)):]))
    print(i)
# Out:
# 44
# 45
# 46
# 47
# 48
# 49
# 50
# 51
# 52

# %%
np.argmax(x9[53])
# Out:
# 44450

# %%
plt.plot(x9[53])
plt.scatter([44440],[x9[53][44440]], color='red')

# %%
h9.append(x9[53][44440]/np.max(x9[53][np.argmin(np.abs(omega9[53]-170)):]))

# %%
plt.plot(h9)

# %%
np.argmax(y9[54][0:30000])
# Out:
# 21957

# %%
np.argmin(y9[54])
# Out:
# 34031

# %%
plt.plot(y9[54])
plt.scatter([34031],[y9[54][34031]], color='red')

# %%
ma9.append(np.argmax(y9[54][0:30000]))
omega9.append((t9[54]-t9[54][np.argmax(x9[54])+30000])*228.1/(-t9[54][np.argmax(x9[54][20000:60000])+20000]+t9[54][np.argmax(x9[54][60000:80000])+60000]))

# %%
plt.plot(omega9[54],x9[54])

# %%
h9.append(np.max(x9[54][20000:60000])/np.max(x9[54][60000:80000]))
h9.append(np.max(x9[55][20000:60000])/np.max(x9[55][60000:80000]))
h9.append(np.max(x9[56][40000:80000])/np.max(x9[56][80000:100000]))
h9.append(np.max(x9[57][40000:80000])/np.max(x9[57][80000:100000]))
h9.append(np.max(x9[58][20000:50000])/np.max(x9[58][50000:70000]))
h9.append(np.max(x9[59][20000:50000])/np.max(x9[59][50000:70000]))
h9.append(np.max(x9[60][20000:50000])/np.max(x9[60][50000:70000]))
h9.append(np.max(x9[61][20000:50000])/np.max(x9[61][50000:70000]))
h9.append(np.max(x9[62][20000:60000])/np.max(x9[62][60000:80000]))
h9.append(np.max(x9[63][20000:60000])/np.max(x9[63][60000:80000]))
h9.append(np.max(x9[64][20000:40000])/np.max(x9[64][50000:60000]))

# %%
k = 64
plt.plot(x9[k])
plt.scatter([np.argmax(x9[k][20000:50000])+20000, np.argmax(x9[k][50000:80000])+50000], [np.max(x9[k][20000:50000]), np.max(x9[k][50000:80000])],color='red')
plt.grid()

# %% [markdown]
# _______________________________________________________

# %%
fr = np.ones(len(h9))*446.79+np.arange(0.00600, 0.00925, 0.00005)

# %%
ev_speed = (2*1.38*10**(-23)*(430+273)/9.988*10**27)**(1/2)

# %%
ev_speed
# Out:
# 1393.775854777242

# %%
plt.figure(figsize=(10,6))
plt.plot(fr, h9)
plt.scatter([446.80005436*(1-ev_speed/3/10**8)], [h9[np.argmin(np.abs(fr-446.80005436*(1-ev_speed/3/10**8)))]], label='теоретический сдвиг нижнего', s=50, color='red')
plt.scatter([446.79982616*(1-ev_speed/3/10**8)], [h9[np.argmin(np.abs(fr-446.79982616*(1-ev_speed/3/10**8)))]], label='теоретический сдвиг верхнего', s=50,color='magenta')
plt.grid()
plt.legend()

# %%
v1 = (fr/446.80005436-1)*300000000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 v1 = (fr/446.80005436-1)*300000000
#
# NameError: name 'fr' is not defined

# %%
v2 = (fr/446.79982616-1)*300000000

# %%
plt.figure(figsize=(10,6))
plt.plot(v1, h9, label='d1')
plt.plot(v2, h9, color='red', label='d2')
plt.grid()

# %%
plt.figure(figsize=(10,6))
plt.plot(np.linspace(-10, 10, 100), -np.exp(-np.power(np.linspace(-10, 10, 100)+1, 2)/20)+np.exp(-np.power(np.linspace(-10, 10, 100)-1, 2)/20))
plt.grid()

# %%
datan = [
    pd.read_csv("data/new/P_5.CSV"),
    pd.read_csv("data/new/P_10.CSV"),
    pd.read_csv("data/new/P_15.CSV"),
    pd.read_csv("data/new/P_20.CSV"),
    pd.read_csv("data/new/P_25.CSV"),
    pd.read_csv("data/new/P_30.CSV"),
    pd.read_csv("data/new/P_35.CSV"),
    pd.read_csv("data/new/P9-700.CSV"),
    pd.read_csv("data/P6-70.CSV")
]

# %%
xn, yn, tn, man,minn,omegan = [],[],[],[],[],[]

# %%
for i in range(len(datan)):
    xn.append(np.array(datan[i].iloc[20000:,1])-datan[i].iloc[20000,1])
    tn.append(np.array(datan[i].iloc[20000:,0])-datan[i].iloc[20000,0])
    yn.append(np.array(datan[i].iloc[50000:,3]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(xn)):
    plt.plot(yn[i])

# %%
for i in range(len(yn)):
    minn.append(np.argmin(yn[i]))
    man.append(np.argmax(yn[i]))

for i in range(len(yn)):
    omegan.append((tn[i]-tn[i][man[i]+30000])*114.1/(-tn[i][man[i]]+tn[i][minn[i]]))

# %%
plt.figure(figsize=(10,6))
for i in range(len(xn)):
    plt.plot(omegan[i],xn[i])

# %%
hn=[]

# %%
for i in range(len(xn)):
    hn.append(np.max(xn[i])/np.max(xn[i][np.argmin(np.abs(omegan[i]-170)):]))

# %%
po = np.array([5, 10, 15, 20, 25, 30, 35, 53.81, 66.35])*10**(-3)/np.pi*4*10**4

# %%
plt.figure(figsize=(6,6))
plt.plot(po, hn)
plt.grid()

# %%
(1393 * 446.79 * 10**(12-8) / 2.99) / 10**6
# Out:
# 2081.533344481605

# %%
(446.80005436*(1-1393/3/10**8) - 446.80005436) * 10**6
# Out:
# -2074.6415857502143

# %%
(446.79982616*(1-1393/3/10**8)-446.79982616)*10**6
# Out:
# -2074.6405261320433

# %%
nu_red = 446.790 + 0.0079
nu_magenta = 446.790 + 0.0077

nu_low = 446.790 + 0.0072

# %%
nur = 446.80005436
num = 446.79982616
c = 299792458

# %%
((num - nu_low) / num) * c
# Out:
# 1762.093258318477

# %%
((4.4 * 10**(-6)) / nur) * c
# Out:
# 2.952297794792059
